# %% [markdown]
# <a href="https://colab.research.google.com/github/shri4916/DS_Assignements/blob/main/Test_Prompt_Amplifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Installation

# %%
#import promp forge
from prompt_amplifier import PromptForge

# Initialize with defaults (TF-IDF embedder, in-memory store)
forge = PromptForge()

# Load your documents
forge.load_documents("/content/Test promp")

# Expand a short prompt
result = forge.expand("How are students doing")
# Out:
# ---------------------------------------------------------------------------
# APIKeyMissingError                        Traceback (most recent call last)
# /tmp/ipython-input-92503346.py in <cell line: 0>()
#       9
#      10 # Expand a short prompt
# ---> 11 result = forge.expand("How are students doing")
#
# /usr/local/lib/python3.12/dist-packages/prompt_amplifier/core/engine.py in expand(self, short_prompt, top_k, system_prompt)
#     452         # Generate expanded prompt
#     453         generation_start = time.time()
# --> 454         gen_result = self.generator.generate(
#     455             prompt=expansion_prompt,
#     456             system_prompt=system_prompt or DEFAULT_SYSTEM_PROMPT,
#
# /usr/local/lib/python3.12/dist-packages/prompt_amplifier/core/engine.py in generator(self)
#     140         """Get or create the LLM generator."""
#     141         if self._generator is None:
# --> 142             self._generator = self._create_default_generator()
# ...
